# %% [markdown]
# # Focused Work
# Refining previous scattershot workbook to reflect focused story.

# %%
from io import StringIO
import os
import requests
import pandas as pd
from dotenv import load_dotenv
# loading variables from .env file
load_dotenv()
apikey = os.getenv('apikey')

# %%
response = requests.get("https://api.twelvedata.com/time_series?apikey=" + apikey + "&interval=1day&start_date=2024-01-01 10:14:00&end_date=2025-07-01 10:14:00&format=CSV&symbol=SPY")

s=response.text
s = s.strip()

spy = pd.read_csv(StringIO(s), sep=';')
spy.to_csv('spy_time_series_2024.csv')

# %%
spy.head()
# Out:
#      datetime       open       high         low      close    volume
# 0  2025-07-01  616.35999  618.83002  615.520020  617.65002  70030100
# 1  2025-06-30  617.38000  619.21997  615.039978  617.84998  92502500
# 2  2025-06-27  612.88000  616.39001  610.830020  614.90997  86258400
# 3  2025-06-26  608.98999  612.31000  608.370000  611.87000  78548400
# 4  2025-06-25  607.90997  608.60999  605.539980  607.12000  62114800

# %%
spy['SPY']=spy['close']

# %%
response = requests.get("https://api.twelvedata.com/time_series?apikey=" + apikey + "&interval=1day&start_date=2024-01-01 10:14:00&end_date=2025-07-01 10:14:00&format=CSV&symbol=MRNA")

s=response.text
s = s.strip()

mrna = pd.read_csv(StringIO(s), sep=';')
mrna.to_csv('mrna_time_series_2024.csv')

# %% [markdown]
# May 24-Jun 3, 2024
# June 24-July 5, 2024
# July 25-Aug 7, 2024
# Nov 1-Nov 22, 2024
# Jan 27-Feb 14, 2024

# %%
mrna_may24_2024 = mrna[(mrna['datetime']>='2024-05-24') &  (mrna['datetime']<='2024-06-03')]

# %%
mrna_june24_2024=mrna[(mrna['datetime']>='2024-06-24') &  (mrna['datetime']<='2024-07-05')]
mrna_july25_2024=mrna[(mrna['datetime']>='2024-07-25') &  (mrna['datetime']<='2024-08-07')]
mrna_nov1_2024=mrna[(mrna['datetime']>='2024-11-01') &  (mrna['datetime']<='2024-11-22')]
mrna_jan27_2025=mrna[(mrna['datetime']>='2025-01-27') &  (mrna['datetime']<='2025-02-14')]

# %%
mrna_may24_2024.to_csv('mrna_may24_2024_timeseries.csv')
mrna_june24_2024.to_csv('mrna_june24_2024_timeseries.csv')
mrna_july25_2024.to_csv('mrna_july25_2024_timeseries.csv')
mrna_nov1_2024.to_csv('mrna_nov1_2024_timeseries.csv')
mrna_jan27_2025.to_csv('mrna_jan27_2025_timeseries.csv')

# %%
mrna_may24_2024.head(10)
# Out:
#        datetime       open       high        low      close   volume  \
# 269  2024-06-03  139.75000  150.80000  137.52000  147.82001  4941500
# 270  2024-05-31  152.10001  158.12900  140.74001  142.55000  7181000
# 271  2024-05-30  150.35001  152.78999  143.52000  151.49001  4667800
# 272  2024-05-29  150.00000  150.00000  140.23000  147.92000  5505900
# 273  2024-05-28  161.64000  164.72501  148.50000  153.20000  6636500
# 274  2024-05-24  163.67500  170.47000  162.00000  166.61000  5045600
#
#        Moderna
# 269  147.82001
# 270  142.55000
# 271  151.49001
# 272  147.92000
# 273  153.20000
# 274  166.61000

# %%
import plotly.graph_objects as go





fig = go.Figure(data=[go.Candlestick(x=mrna['datetime'],
                open=mrna['open'],
                high=mrna['high'],
                low=mrna['low'],
                close=mrna['close'])])

fig.update_layout(title='MODERNA 2024-Present',
                      xaxis_rangeslider_visible=False)

fig.show()

# %%
sandp500=pd.read_csv('S&P 500 Historical Data.csv')

# %%
sandp500.head()
# Out:
#       Date    Price     Open     High      Low  Vol. Change %
# 0   7/1/25  6198.01  6187.25  6210.78  6177.97   NaN   -0.11%
# 1  6/30/25  6204.95  6193.36  6215.08  6174.97   NaN    0.52%
# 2  6/27/25  6173.07  6150.70  6187.68  6132.35   NaN    0.52%
# 3  6/26/25  6141.02  6112.09  6146.52  6107.27   NaN    0.80%
# 4  6/25/25  6092.16  6104.23  6108.51  6080.09   NaN    0.00%

# %%
sandp500['SandP500']=sandp500['Price']

# %%
sandp500.dtypes
# Out:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.        float64
# Change %     object
# dtype: object

# %%
import plotly.express as px


fig = px.line(sandp500, x="Date", y="Price", title='S & P 500')
fig.show()

# %%
fig.update_layout(
    xaxis=dict(autorange='reversed')
)

# %%
fig = go.Figure(data=[go.Candlestick(x=mrna['datetime'],
                open=mrna['open'],
                high=mrna['high'],
                low=mrna['low'],
                close=mrna['close'])])

fig.update_layout(title='MODERNA 2024-Present',
                      xaxis_rangeslider_visible=False)

fig.show()

# %%
response = requests.get("https://api.twelvedata.com/time_series?apikey=" + apikey + "&interval=1day&start_date=2024-01-01 10:14:00&end_date=2025-07-01 10:14:00&format=CSV&symbol=PPC")

s=response.text
s = s.strip()

ppc = pd.read_csv(StringIO(s), sep=';')
ppc.to_csv('ppc_time_series_2024.csv')

# %%
fig = go.Figure(data=[go.Candlestick(x=ppc['datetime'],
                open=ppc['open'],
                high=ppc['high'],
                low=ppc['low'],
                close=ppc['close'])])

fig.update_layout(title='Pilgrims Pride 2024-Present',
                      xaxis_rangeslider_visible=False)

fig.show()

# %%
response = requests.get("https://api.twelvedata.com/time_series?apikey=" + apikey + "&interval=1day&start_date=2024-01-01 10:14:00&end_date=2025-07-01 10:14:00&format=CSV&symbol=TSN")

s=response.text
s = s.strip()

tsn = pd.read_csv(StringIO(s), sep=';')
tsn.to_csv('tsn_time_series_2024.csv')

# %%
fig = go.Figure(data=[go.Candlestick(x=tsn['datetime'],
                open=tsn['open'],
                high=tsn['high'],
                low=tsn['low'],
                close=tsn['close'])])

fig.update_layout(title="Tyson's 2024-Present",
                      xaxis_rangeslider_visible=False)

fig.show()

# %%
response = requests.get("https://api.twelvedata.com/time_series?apikey=" + apikey + "&interval=1day&start_date=2024-01-01 10:14:00&end_date=2025-07-01 10:14:00&format=CSV&symbol=HRL")

s=response.text
s = s.strip()

hrl = pd.read_csv(StringIO(s), sep=';')
hrl.to_csv('hrl_time_series_2024.csv')

# %%
fig = go.Figure(data=[go.Candlestick(x=hrl['datetime'],
                open=hrl['open'],
                high=hrl['high'],
                low=hrl['low'],
                close=hrl['close'])])

fig.update_layout(title="Hormel 2024-Present",
                      xaxis_rangeslider_visible=False)

fig.show()

# %%
response = requests.get("https://api.twelvedata.com/time_series?apikey=" + apikey + "&interval=1day&start_date=2024-01-01 10:14:00&end_date=2025-07-01 10:14:00&format=CSV&symbol=PFE")

s=response.text
s = s.strip()

pfe = pd.read_csv(StringIO(s), sep=';')
pfe.to_csv('pfe_time_series_2024.csv')

# %%
fig = go.Figure(data=[go.Candlestick(x=pfe['datetime'],
                open=pfe['open'],
                high=pfe['high'],
                low=pfe['low'],
                close=pfe['close'])])

fig.update_layout(title="Pfizer 2024-Present",
                      xaxis_rangeslider_visible=False)

fig.show()

# %%
response = requests.get("https://api.twelvedata.com/time_series?apikey=" + apikey + "&interval=1day&start_date=2024-01-01 10:14:00&end_date=2025-07-01 10:14:00&format=CSV&symbol=RHHBY")

s=response.text
s = s.strip()

rhhby = pd.read_csv(StringIO(s), sep=';')
rhhby.to_csv('rhhby_time_series_2024.csv')

# %%
fig = go.Figure(data=[go.Candlestick(x=rhhby['datetime'],
                open=rhhby['open'],
                high=rhhby['high'],
                low=rhhby['low'],
                close=rhhby['close'])])

fig.update_layout(title="Roche 2024-Present",
                      xaxis_rangeslider_visible=False)

fig.show()

# %%
rhhby.head()
# Out:
#      datetime   open   high    low  close   volume
# 0  2025-07-01  40.79  41.26  40.74  41.15   778100
# 1  2025-06-30  40.78  40.89  40.50  40.76   782800
# 2  2025-06-27  41.02  41.09  40.66  40.91   937700
# 3  2025-06-26  40.84  41.25  40.79  41.18  2173900
# 4  2025-06-25  40.32  40.35  40.13  40.29  1054500

# %%
ppc['PilgrimPride']=ppc['close']
tsn['Tysons']=tsn['close']
hrl['Hormel']=hrl['close']
rhhby['Roche']=rhhby['close']
pfe['Pfizer']=pfe['close']
mrna['Moderna']=mrna['close']

ppc_holder=ppc[['datetime','PilgrimPride']]

# %%
all_close=pd.concat([ppc_holder,tsn['Tysons'],hrl['Hormel'], rhhby['Roche'],pfe['Pfizer'],mrna['Moderna'],spy['SPY']], axis=1, join='inner')

# %%
all_close.head()
# Out:
#      datetime  PilgrimPride  Tysons  Hormel  Roche     Pfizer  Moderna  \
# 0  2025-07-01         45.49   57.35   30.70  41.15  25.040001    28.69
# 1  2025-06-30         44.98   55.94   30.25  40.76  24.240000    27.59
# 2  2025-06-27         44.56   55.24   30.47  40.91  24.190000    27.16
# 3  2025-06-26         44.55   55.02   30.25  41.18  24.240000    27.54
# 4  2025-06-25         44.91   54.64   29.84  40.29  24.260000    26.86
#
#          SPY
# 0  617.65002
# 1  617.84998
# 2  614.90997
# 3  611.87000
# 4  607.12000

# %%
all_close.to_csv('all_close.csv')

# %%
wild = pd.read_csv("HPAI Detections in Wild Birds.csv", parse_dates=['Date Detected'])

# %%
wild.head()
# Out:
#       State        County Collection Date Date Detected HPAI Strain  \
# 0   Florida  Hillsborough       3/20/2025    2025-07-03  EA/AM H5N1
# 1   Florida  Hillsborough       3/20/2025    2025-07-03  EA/AM H5N1
# 2   Florida       Brevard      11/26/2024    2025-07-03  EA/AM H5N1
# 3  New York    Chautauqua       3/17/2025    2025-07-03       EA H5
# 4  New York          Erie       3/17/2025    2025-07-03  EA/AM H5N1
#
#     Bird Species WOAH Classification      Sampling Method  \
# 0     Bald eagle           Wild bird  Morbidity/Mortality
# 1     Bald eagle           Wild bird  Morbidity/Mortality
# 2  Black vulture           Wild bird  Morbidity/Mortality
# 3     Bald eagle           Wild bird  Morbidity/Mortality
# 4     Bald eagle           Wild bird  Morbidity/Mortality
#
#                      Submitting Agency
# 0  Private (non-government) submission
# 1  Private (non-government) submission
# 2                              FL FWCC
# 3                               NY DEC
# ...

# %%
wild = pd.read_csv('HPAI Detections in Wild Birds.csv', parse_dates=['Collection Date'], na_values='Unknown')

# %%
wild.dtypes
# Out:
# State                          object
# County                         object
# Collection Date        datetime64[ns]
# Date Detected                  object
# HPAI Strain                    object
# Bird Species                   object
# WOAH Classification            object
# Sampling Method                object
# Submitting Agency              object
# dtype: object

# %%
wild.head(120)
# Out:
#           State         County Collection Date Date Detected HPAI Strain  \
# 0       Florida   Hillsborough      2025-03-20      7/3/2025  EA/AM H5N1
# 1       Florida   Hillsborough      2025-03-20      7/3/2025  EA/AM H5N1
# 2       Florida        Brevard      2024-11-26      7/3/2025  EA/AM H5N1
# 3      New York     Chautauqua      2025-03-17      7/3/2025       EA H5
# 4      New York           Erie      2025-03-17      7/3/2025  EA/AM H5N1
# ..          ...            ...             ...           ...         ...
# 115  California         Orange      2024-12-23     6/26/2025       EA H5
# 116  California  San Francisco             NaT     6/25/2025  EA/AM H5N1
# 117  California  San Francisco             NaT     6/25/2025  EA/AM H5N1
# 118  California  San Francisco             NaT     6/25/2025  EA/AM H5N1
# 119  California  San Francisco             NaT     6/25/2025  EA/AM H5N1
#
#       Bird Species WOAH Classification      Sampling Method  \
# ...

# %%
wild.dropna(subset=['Collection Date'])
# Out:
#                 State        County Collection Date Date Detected HPAI Strain  \
# 0             Florida  Hillsborough      2025-03-20      7/3/2025  EA/AM H5N1
# 1             Florida  Hillsborough      2025-03-20      7/3/2025  EA/AM H5N1
# 2             Florida       Brevard      2024-11-26      7/3/2025  EA/AM H5N1
# 3            New York    Chautauqua      2025-03-17      7/3/2025       EA H5
# 4            New York          Erie      2025-03-17      7/3/2025  EA/AM H5N1
# ...               ...           ...             ...           ...         ...
# 13547  South Carolina      Colleton      2021-12-30     1/13/2022     EA H5N1
# 13548  South Carolina      Colleton      2021-12-30     1/13/2022     EA H5N1
# 13549  North Carolina          Hyde      2021-12-30     1/12/2022       EA H5
# 13550  North Carolina          Hyde      2021-12-30     1/12/2022     EA H5N1
# 13551        Virginia       Henrico      2024-12-19           NaN  EA/AM H5N1
#
# ...

# %%
month_counts = wild['Collection Date'].dt.to_period('M').value_counts().sort_index()

# %%
month_counts
# Out:
# Collection Date
# 2021-12       4
# 2022-01     231
# 2022-02     186
# 2022-03     462
# 2022-04     750
# 2022-05     467
# 2022-06     245
# 2022-07     137
# 2022-08     415
# 2022-09    1098
# 2022-10     797
# 2022-11     977
# 2022-12     639
# 2023-01     383
# 2023-02     136
# 2023-03      92
# 2023-04      78
# 2023-05      31
# 2023-06       8
# 2023-07      14
# 2023-08      39
# 2023-09     158
# 2023-10     658
# 2023-11     868
# 2023-12     568
# 2024-01     354
# 2024-02     250
# 2024-03     109
# 2024-04      54
# 2024-05      55
# 2024-06      28
# 2024-07      48
# 2024-08       8
# 2024-09      30
# 2024-10     210
# 2024-11     610
# 2024-12    1072
# 2025-01     507
# 2025-02     352
# 2025-03     127
# 2025-04      41
# 2025-05      51
# 2025-06       5
# Freq: M, Name: count, dtype: int64

# %%
month_counts.to_csv('month_counts_wild.csv')

# %%
flock=pd.read_csv('FUCK.csv',  parse_dates=['Outbreak Date'])

# %%
flock.head
# Out:
# <bound method NDFrame.head of        FullGeoName  FIPS Codes County Name        State Outbreak Date  \
# 0       OH, Mercer       39107      Mercer         Ohio    2025-01-15
# 1       MO, Newton       29145      Newton     Missouri    2025-01-14
# 2      PR, Culebra       72049     Culebra  Puerto Rico    2025-01-13
# 3     TX, Brazoria       48039    Brazoria        Texas    2025-01-09
# 4       TX, Burnet       48053      Burnet        Texas    2025-01-09
# ..             ...         ...         ...          ...           ...
# 601     IN, Greene       18055      Greene      Indiana    2022-02-23
# 602  MI, Kalamazoo       26077   Kalamazoo     Michigan    2022-02-23
# 603    KY, Webster       21233     Webster     Kentucky    2022-02-15
# 604   VA, Fauquier       51061    Fauquier     Virginia    2022-02-12
# 605     KY, Fulton       21075      Fulton     Kentucky    2022-02-12
#
#                         Flock Type  Flock Size  State Count  Outbreaks  \
# ...

# %%
flock.dtypes
# Out:
# FullGeoName              object
# FIPS Codes                int64
# County Name              object
# State                    object
# Outbreak Date    datetime64[ns]
# Flock Type               object
# Flock Size                int64
# State Count               int64
# Outbreaks                 int64
# Counties                  int64
# dtype: object

# %%
flock['Flock Size'].astype('Int64')
# Out:
# 0         4500
# 1      1585100
# 2          240
# 3           30
# 4           10
#         ...
# 601      63600
# 602         30
# 603      53300
# 604         90
# 605     231400
# Name: Flock Size, Length: 606, dtype: Int64

# %%
flock_month= flock['Outbreak Date'].dt.to_period('M').value_counts().sort_index()

# %%
flock_month
# Out:
# Outbreak Date
# 2022-02     6
# 2022-03    31
# 2022-04    41
# 2022-05    30
# 2022-06     4
# 2022-07     2
# 2022-08     8
# 2022-09    33
# 2022-10    47
# 2022-11    41
# 2022-12    45
# 2023-01     6
# 2023-02    11
# 2023-03    17
# 2023-04     8
# 2023-05     4
# 2023-08     1
# 2023-09     1
# 2023-10    15
# 2023-11    47
# 2023-12    44
# 2024-01     6
# 2024-02    13
# 2024-03     4
# 2024-04     5
# 2024-05     5
# 2024-06     3
# 2024-07     2
# 2024-09     2
# 2024-10     6
# 2024-11    23
# 2024-12    82
# 2025-01    13
# Freq: M, Name: count, dtype: int64

# %%
# Out:
# Date Detected  Date Detected
# 1.0            2023-01-04       88
#                2023-01-18       81
#                2025-01-13       80
#                2025-01-28       78
#                2025-01-02       75
#                                 ..
# 12.0           2023-12-05        3
#                2022-12-19        1
#                2023-12-01        1
#                2023-12-27        1
#                2024-12-27        1
# Name: count, Length: 579, dtype: int64

# %%
flock_size=flock.groupby(flock['Outbreak Date'].dt.to_period('M'))['Flock Size'].sum()

# %%
flock_size
# Out:
# Outbreak Date
# 2022-02      348490
# 2022-03     9740319
# 2022-04      773135
# 2022-05      109206
# 2022-06        1163
# 2022-07         140
# 2022-08         402
# 2022-09     9668072
# 2022-10      319879
# 2022-11     9091623
# 2022-12    23765895
# 2023-01       23900
# 2023-02      109789
# 2023-03       72850
# 2023-04       67620
# 2023-05         232
# 2023-08        3260
# 2023-09         520
# 2023-10     2200783
# 2023-11     7148844
# 2023-12    18464430
# 2024-01       42050
# 2024-02      314779
# 2024-03         500
# 2024-04     2108220
# 2024-05     6554260
# 2024-06      281830
# 2024-07       91805
# 2024-09        4500
# 2024-10     3363136
# 2024-11     5854455
# 2024-12    30876124
# 2025-01     4925183
# Freq: M, Name: Flock Size, dtype: int64

# %%
flock_size.to_csv('flock_size.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 flock_size.to_csv('flock_size.csv', parse_dates=['Date'])
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'parse_dates'

# %%
news = pd.read_csv('news_birdflu.csv', parse_dates=['Date'])
# Out:
# /var/folders/5y/v8b35sxn6_s4bcz1qk12mq_m0000gn/T/ipykernel_60010/2304296640.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
news.dtypes
# Out:
# Date              datetime64[ns]
# Outlet                    object
# URL                       object
# Specific_Stock            object
# Cites_data                object
# Other_data                object
# Advertorial               object
# dtype: object

# %%
news_line=news['Date'].dt.to_period('M').value_counts().sort_index()

# %%
news_line
# Out:
# Date
# 2024-04     4
# 2024-05     4
# 2024-06     5
# 2024-07     2
# 2024-09     2
# 2024-10     2
# 2024-11     3
# 2024-12     4
# 2025-01    10
# 2025-02     5
# 2025-03     2
# 2025-04     7
# 2025-05     2
# 2025-06     2
# 2025-12     1
# Freq: M, Name: count, dtype: int64

# %%
news_line.to_csv('news_line.csv')

# %%
reddit = pd.read_csv('reddit_birdflu.csv', parse_dates=['DATE'])
# Out:
# /var/folders/5y/v8b35sxn6_s4bcz1qk12mq_m0000gn/T/ipykernel_60010/3409597189.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
reddit_line=reddit['DATE'].dt.to_period('M').value_counts().sort_index()

# %%
reddit_line
# Out:
# DATE
# 2024-04    5
# 2024-05    6
# 2024-06    5
# 2024-07    1
# 2024-11    1
# 2024-12    2
# 2025-01    5
# 2025-03    1
# 2025-05    1
# Freq: M, Name: count, dtype: int64

# %%
reddit_line.to_csv('reddit_line.csv')
